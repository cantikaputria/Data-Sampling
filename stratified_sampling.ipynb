# %%
# Import package
import numpy as np
import pandas as pd
 
# Buat data frame dengan membaca dataset
df = pd.read_csv("../Dataset/students.csv")

# Tampilkan sample data berdasarkan race/ethnicity
df.groupby('race/ethnicity', group_keys=False).apply(lambda x: x.sample(frac=0.1))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 943    male        group A            some high school  free/reduced
# 972  female        group A                 high school  free/reduced
# 576    male        group A                some college      standard
# 769    male        group A                some college  free/reduced
# 13     male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 32   female        group E             master's degree  free/reduced
# 881  female        group E           bachelor's degree      standard
# 755  female        group E          associate's degree      standard
# 97   female        group E                some college      standard
# 349    male        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Import package pandas
import pandas as pd
  
# Buat data frame dengan membaca dataset
data = pd.read_csv("../Dataset/students.csv")
  
# Generate sample 1% dari keseluruhan dataset
rows = data.sample(frac = 0.1)

# Cek jika sample sama dengan 1% dari data atau tidak
if (0.1*(len(data)) == len(rows)):
    print("Total Sample :", len(rows))
    print("Total Data :", len(data))

# Tampilkan data
rows
# Out:
# Total Sample : 100
# Total Data : 1000
#      gender race/ethnicity parental level of education         lunch  \
# 668    male        group C                some college      standard
# 563  female        group D                some college  free/reduced
# 475  female        group D           bachelor's degree      standard
# 924    male        group D                 high school  free/reduced
# 628    male        group D                some college  free/reduced
# ..      ...            ...                         ...           ...
# 709  female        group D          associate's degree  free/reduced
# 140  female        group D            some high school      standard
# 419    male        group E                 high school  free/reduced
# 130    male        group D             master's degree      standard
# 194  female        group C             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...
